# %%
# %reset -f

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#    Unnamed: 0 class_type    wristX    wristY        wristZ  thumb_CmcX  \
# 0           0  hold_drag  0.718277  0.755932 -1.002445e-06    0.628396
# 1           1  hold_drag  0.784256  0.382844 -2.865099e-07    0.746344
# 2           2  hold_drag  0.817233  0.384959 -3.290068e-07    0.778067
# 3           3  hold_drag  0.808122  0.405828 -3.202076e-07    0.771413
# 4           4  hold_drag  0.807614  0.723678 -8.603932e-07    0.718522
#
#    thumb_CmcY  thumb_CmcZ  thumb_McpX  thumb_McpY  ...  pinky_McpZ  \
# 0    0.733559   -0.040165    0.550952    0.666625  ...   -0.060510
# 1    0.374087   -0.039294    0.729566    0.356641  ...   -0.025767
# 2    0.376026   -0.036912    0.759743    0.358693  ...   -0.026174
# 3    0.395701   -0.035655    0.754096    0.379873  ...   -0.021703
# 4    0.697832   -0.019340    0.643817    0.637320  ...   -0.040156
#
#    pinky_PipX  pinky_PipY  pinky_PipZ  pinky_DipX  pinky_DipY  pinky_DipZ  \
# 0    0.821505    0.565546   -0.089127    0.794926    0.600558   -0.069126
# 1    0.843575    0.319860   -0.042587    0.839551    0.332689   -0.036216
# 2    0.876751    0.321933   -0.042140    0.871503    0.334271   -0.035899
# 3    0.868737    0.343020   -0.037612    0.864210    0.355314   -0.031152
# 4    0.820538    0.545987   -0.057530    0.815629    0.589338   -0.037375
#
#    pinky_TipX  pinky_TipY  pinky_TipZ
# 0    0.785816    0.618257   -0.045401
# 1    0.830073    0.337648   -0.028362
# 2    0.859615    0.339383   -0.028031
# 3    0.851220    0.360532   -0.022936
# 4    0.830387    0.603487   -0.015159
#
# [5 rows x 65 columns]

# %%
data = data.drop(columns=['Unnamed: 0'])
data.head()
# Out:
#   class_type    wristX    wristY        wristZ  thumb_CmcX  thumb_CmcY  \
# 0  hold_drag  0.718277  0.755932 -1.002445e-06    0.628396    0.733559
# 1  hold_drag  0.784256  0.382844 -2.865099e-07    0.746344    0.374087
# 2  hold_drag  0.817233  0.384959 -3.290068e-07    0.778067    0.376026
# 3  hold_drag  0.808122  0.405828 -3.202076e-07    0.771413    0.395701
# 4  hold_drag  0.807614  0.723678 -8.603932e-07    0.718522    0.697832
#
#    thumb_CmcZ  thumb_McpX  thumb_McpY  thumb_McpZ  ...  pinky_McpZ  \
# 0   -0.040165    0.550952    0.666625   -0.058387  ...   -0.060510
# 1   -0.039294    0.729566    0.356641   -0.061021  ...   -0.025767
# 2   -0.036912    0.759743    0.358693   -0.057455  ...   -0.026174
# 3   -0.035655    0.754096    0.379873   -0.055003  ...   -0.021703
# 4   -0.019340    0.643817    0.637320   -0.026068  ...   -0.040156
#
#    pinky_PipX  pinky_PipY  pinky_PipZ  pinky_DipX  pinky_DipY  pinky_DipZ  \
# 0    0.821505    0.565546   -0.089127    0.794926    0.600558   -0.069126
# 1    0.843575    0.319860   -0.042587    0.839551    0.332689   -0.036216
# 2    0.876751    0.321933   -0.042140    0.871503    0.334271   -0.035899
# 764     0.188923    0.620013   -0.043443    0.207272    0.662708   -0.043703
# 543     0.198218    0.410783   -0.055796    0.200271    0.462843   -0.045849
# 423     0.891495    0.516235   -0.061222    0.876812    0.597040   -0.049251
# 1120    0.235940    0.409681   -0.039966    0.242441    0.475176   -0.030580
#
#       pinky_TipX  pinky_TipY  pinky_TipZ
# 599     0.779318    0.336427   -0.006598
# 764     0.216996    0.696729   -0.037159
# 543     0.203887    0.480284   -0.033383
# 423     0.865197    0.652379   -0.032402
# 1120    0.240657    0.509510   -0.017242
#
# [5 rows x 63 columns]

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
import pickle
svc_model  = SVC(kernel='poly')
svc_model.fit(x_train, y_train)
print("**********poly***********")
prediction = svc_model .predict(x_test)
# check the accuracy on the training set
print("training",svc_model.score(x_train, y_train))
print("validation",svc_model.score(x_test, y_test))
filename = 'svc_model_3.sav'
pickle.dump(svc_model, open(filename, 'wb'))
# Out:
# **********poly***********
# training 0.7814569536423841
# validation 0.7623762376237624

# %%
prediction
# Out:
# array(['hold_drag', 'pointer', 'scrolldown', 'hold_drag', 'hold_drag',
#        'scrollup', 'hold_drag', 'left_arrow', 'right_click',
#        'right_arrow', 'pointer', 'left_click', 'hold_drag', 'hold_drag',
#        'pointer', 'hold_drag', 'right_arrow', 'pointer', 'hold_drag',
#        'pointer', 'pointer', 'left_click', 'left_click', 'hold_drag',
#        'left_click', 'right_arrow', 'left_click', 'hold_drag', 'scrollup',
#        'scrollup', 'hold_drag', 'left_arrow', 'left_dbl_click',
#        'hold_drag', 'hold_drag', 'left_click', 'hold_drag', 'hold_drag',
#        'pointer', 'pointer', 'hold_drag', 'pointer', 'hold_drag',
#        'hold_drag', 'hold_drag', 'hold_drag', 'right_arrow', 'hold_drag',
#        'pointer', 'hold_drag', 'left_click', 'left_click', 'hold_drag',
#        'pointer', 'left_click', 'hold_drag', 'left_click', 'hold_drag',
#        'pointer', 'right_click', 'hold_drag', 'hold_drag', 'left_click',
#        'left_click', 'left_arrow', 'right_click', 'right_click',
#        'left_dbl_click', 'left_click', 'hold_drag', 'left_dbl_click',
#        'left_dbl_click', 'left_arrow', 'pointer', 'pointer', 'hold_drag',
#        'pointer', 'hold_drag', 'pointer', 'hold_drag', 'left_click',
#        'hold_drag', 'pointer', 'hold_drag', 'hold_drag', 'hold_drag',
#        'pointer', 'hold_drag', 'hold_drag', 'left_click', 'left_click',
#        'pointer', 'right_click', 'right_click', 'hold_drag', 'pointer',
#        'left_dbl_click', 'left_click', 'left_click', 'left_dbl_click',
#        'left_click', 'left_click', 'pointer', 'pointer', 'pointer',
#        'pointer', 'pointer', 'hold_drag', 'hold_drag', 'hold_drag',
#        'pointer', 'right_arrow', 'hold_drag', 'hold_drag', 'pointer',
#        'hold_drag', 'hold_drag', 'right_click', 'right_click', 'scrollup',
#        'hold_drag', 'pointer', 'hold_drag', 'pointer', 'pointer',
#        'left_click', 'left_click', 'hold_drag', 'hold_drag', 'pointer',
#        'pointer', 'left_dbl_click', 'right_click', 'hold_drag',
#        'left_dbl_click', 'scrolldown', 'hold_drag', 'hold_drag',
#        'hold_drag', 'left_dbl_click', 'pointer', 'pointer', 'scrollup',
#        'hold_drag', 'hold_drag', 'pointer', 'pointer', 'hold_drag',
#        'pointer', 'left_click', 'hold_drag', 'pointer', 'pointer',
#        'pointer', 'right_click', 'right_click', 'pointer', 'pointer',
#        'left_arrow', 'hold_drag', 'right_click', 'pointer', 'hold_drag',
#        'hold_drag', 'left_click', 'left_click', 'pointer', 'pointer',
#        'hold_drag', 'hold_drag', 'pointer', 'pointer', 'pointer',
#        'hold_drag', 'hold_drag', 'left_dbl_click', 'pointer', 'pointer',
#        'hold_drag', 'left_click', 'hold_drag', 'scrolldown', 'pointer',
#        'pointer', 'pointer', 'left_dbl_click', 'right_arrow', 'hold_drag',
#        'hold_drag', 'left_click', 'left_dbl_click', 'scrollup',
#        'scrolldown', 'scrollup', 'pointer', 'hold_drag', 'right_click',
#        'right_click', 'pointer', 'hold_drag', 'hold_drag', 'hold_drag',
#        'hold_drag', 'left_click', 'scrolldown', 'hold_drag', 'pointer',
#        'left_click', 'hold_drag', 'hold_drag', 'hold_drag', 'left_click',
#        'pointer', 'pointer', 'hold_drag', 'hold_drag', 'hold_drag',
#        'hold_drag', 'pointer', 'hold_drag', 'pointer', 'pointer',
#        'hold_drag', 'hold_drag', 'hold_drag', 'hold_drag',
#        'left_dbl_click', 'left_click', 'hold_drag', 'hold_drag',
#        'hold_drag', 'hold_drag', 'right_arrow', 'hold_drag', 'scrolldown',
#        'pointer', 'left_click', 'pointer', 'right_arrow', 'pointer',
#        'pointer', 'right_arrow', 'right_arrow', 'pointer', 'hold_drag',
#        'scrolldown', 'right_arrow', 'hold_drag', 'right_click',
#        'hold_drag', 'hold_drag', 'hold_drag', 'hold_drag', 'hold_drag',
#        'pointer', 'pointer', 'left_click', 'left_click', 'left_click',
#        'left_click', 'pointer', 'pointer', 'pointer', 'left_dbl_click',
#        'hold_drag', 'pointer', 'hold_drag', 'scrollup', 'hold_drag',
#        'scrollup', 'hold_drag', 'left_arrow', 'left_click', 'left_arrow',
#        'hold_drag', 'left_dbl_click', 'left_arrow', 'pointer',
#        'left_dbl_click', 'pointer', 'left_dbl_click', 'right_arrow',
#        'left_arrow', 'pointer', 'pointer', 'pointer', 'right_arrow',
#        'hold_drag', 'hold_drag', 'left_dbl_click', 'hold_drag',
#        'right_arrow', 'hold_drag', 'scrolldown', 'left_arrow', 'pointer',
#        'hold_drag', 'right_click', 'pointer', 'pointer', 'hold_drag',
#        'right_arrow', 'pointer'], dtype=object)

# %%
from sklearn.svm import SVC
import pickle
  
# Building a Support Vector Machine on train data
svc_model = SVC(C= .1, kernel='linear', gamma= 1)
svc_model.fit(x_train, y_train)
print("**********linear***********")
prediction = svc_model .predict(x_test)
# check the accuracy on the training set
print("training",svc_model.score(x_train, y_train))
print("validation",svc_model.score(x_test, y_test))

svc_model = SVC(kernel='rbf')
svc_model.fit(x_train, y_train)
print("**********rbf***********")
prediction = svc_model .predict(x_test)
# check the accuracy on the training set
print("training",svc_model.score(x_train, y_train))
print("validation",svc_model.score(x_test, y_test))


svc_model  = SVC(kernel='poly')
svc_model.fit(x_train, y_train)
print("**********poly***********")
prediction = svc_model .predict(x_test)
# check the accuracy on the training set
print("training",svc_model.score(x_train, y_train))
print("validation",svc_model.score(x_test, y_test))
filename = 'svc_model_3.sav'
pickle.dump(svc_model, open(filename, 'wb'))

svc_model  = SVC(kernel='sigmoid')
svc_model.fit(x_train, y_train)
print("**********sigmoid***********")
prediction = svc_model .predict(x_test)
# check the accuracy on the training set
print("training",svc_model.score(x_train, y_train))
print("validation",svc_model.score(x_test, y_test))
# Out:
# **********linear***********
# training 0.5687086092715232
# validation 0.5907590759075908
# **********rbf***********
# training 0.7077814569536424
# validation 0.6666666666666666
# **********poly***********
# training 0.7814569536423841
# validation 0.7623762376237624
# **********sigmoid***********
# training 0.21274834437086093
# validation 0.1782178217821782

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(x_train, y_train)
prediction_results = knn.predict(x_test)
filename = 'knn_model.sav'
pickle.dump(knn, open(filename, 'wb'))
print(prediction_results)
print("training",knn.score(x_train, y_train))
print("validation",knn.score(x_test, y_test))
# Out:
# ['hold_drag' 'left_click' 'scrolldown' 'hold_drag' 'hold_drag' 'hold_drag'
#  'hold_drag' 'left_arrow' 'right_click' 'right_arrow' 'pointer'
#  'left_click' 'hold_drag' 'pointer' 'left_click' 'pointer' 'right_arrow'
#  'pointer' 'right_click' 'left_click' 'left_click' 'left_click'
#  'left_click' 'hold_drag' 'left_click' 'right_arrow' 'left_click'
#  'hold_drag' 'scrollup' 'scrollup' 'hold_drag' 'left_arrow' 'hold_drag'
#  'hold_drag' 'hold_drag' 'left_click' 'left_dbl_click' 'hold_drag'
#  'pointer' 'pointer' 'pointer' 'hold_drag' 'hold_drag' 'hold_drag'
#  'hold_drag' 'hold_drag' 'right_arrow' 'hold_drag' 'pointer' 'left_click'
#  'left_click' 'left_click' 'hold_drag' 'pointer' 'left_click' 'hold_drag'
#  'left_click' 'pointer' 'pointer' 'right_click' 'hold_drag' 'hold_drag'
#  'pointer' 'left_click' 'left_arrow' 'right_click' 'pointer' 'pointer'
#  'left_click' 'hold_drag' 'left_dbl_click' 'left_dbl_click' 'left_arrow'
#  'left_click' 'pointer' 'hold_drag' 'pointer' 'hold_drag' 'left_click'
#  'hold_drag' 'left_click' 'hold_drag' 'pointer' 'pointer' 'hold_drag'
#  'hold_drag' 'left_click' 'hold_drag' 'hold_drag' 'left_click' 'hold_drag'
#  'left_click' 'right_click' 'left_click' 'left_click' 'pointer'
#  'left_dbl_click' 'left_click' 'pointer' 'left_click' 'left_click'
#  'left_click' 'left_click' 'pointer' 'left_click' 'pointer' 'left_click'
#  'left_click' 'hold_drag' 'hold_drag' 'pointer' 'right_arrow' 'hold_drag'
#  'pointer' 'right_click' 'hold_drag' 'pointer' 'right_click' 'left_click'
#  'scrollup' 'hold_drag' 'pointer' 'hold_drag' 'pointer' 'pointer'
#  'left_click' 'left_click' 'hold_drag' 'hold_drag' 'hold_drag' 'hold_drag'
#  'left_dbl_click' 'hold_drag' 'hold_drag' 'left_dbl_click' 'scrolldown'
#  'hold_drag' 'hold_drag' 'hold_drag' 'left_dbl_click' 'left_click'
#  'hold_drag' 'scrollup' 'pointer' 'hold_drag' 'left_click' 'left_click'
#  'pointer' 'pointer' 'pointer' 'hold_drag' 'hold_drag' 'left_click'
#  'left_click' 'pointer' 'hold_drag' 'hold_drag' 'left_click' 'left_arrow'
#  'hold_drag' 'right_click' 'pointer' 'hold_drag' 'hold_drag' 'left_click'
#  'left_click' 'left_click' 'hold_drag' 'left_click' 'hold_drag' 'pointer'
#  'left_click' 'left_click' 'pointer' 'hold_drag' 'left_dbl_click'
#  'left_click' 'pointer' 'hold_drag' 'hold_drag' 'hold_drag' 'scrolldown'
#  'hold_drag' 'pointer' 'pointer' 'left_dbl_click' 'right_arrow'
#  'hold_drag' 'right_click' 'pointer' 'left_dbl_click' 'scrollup'
#  'scrolldown' 'pointer' 'pointer' 'hold_drag' 'right_click' 'pointer'
#  'pointer' 'left_click' 'left_click' 'hold_drag' 'hold_drag' 'left_click'
#  'pointer' 'hold_drag' 'left_click' 'left_click' 'pointer' 'hold_drag'
#  'hold_drag' 'pointer' 'left_click' 'left_click' 'hold_drag' 'hold_drag'
#  'hold_drag' 'hold_drag' 'left_click' 'hold_drag' 'pointer' 'left_click'
#  'pointer' 'hold_drag' 'hold_drag' 'hold_drag' 'left_dbl_click'
#  'left_click' 'hold_drag' 'left_click' 'hold_drag' 'hold_drag'
#  'right_arrow' 'left_click' 'scrolldown' 'left_click' 'left_click'
#  'left_click' 'right_arrow' 'pointer' 'left_dbl_click' 'right_arrow'
#  'right_arrow' 'pointer' 'pointer' 'scrolldown' 'right_arrow' 'hold_drag'
#  'pointer' 'hold_drag' 'right_click' 'hold_drag' 'pointer' 'left_click'
#  'pointer' 'left_click' 'left_click' 'hold_drag' 'left_click' 'pointer'
#  'left_click' 'pointer' 'pointer' 'left_dbl_click' 'hold_drag'
#  'left_click' 'left_click' 'scrollup' 'hold_drag' 'hold_drag' 'hold_drag'
#  'left_arrow' 'left_click' 'left_arrow' 'hold_drag' 'pointer' 'left_arrow'
#  'pointer' 'pointer' 'pointer' 'left_dbl_click' 'right_arrow' 'left_arrow'
#  'pointer' 'pointer' 'left_click' 'right_arrow' 'hold_drag' 'hold_drag'
#  'left_dbl_click' 'hold_drag' 'right_arrow' 'hold_drag' 'scrolldown'
#  'left_arrow' 'pointer' 'hold_drag' 'pointer' 'left_click' 'pointer'
#  'hold_drag' 'right_arrow' 'pointer']
# training 0.8352649006622517
# validation 0.6666666666666666

# %% [markdown]
# Decision Tree

# %%
from sklearn import tree
dtc = tree.DecisionTreeClassifier()

dtc.fit(x_train, y_train)
prediction_results = dtc.predict(x_test)
print(prediction_results)
print("training",dtc.score(x_train, y_train))
print("validation",dtc.score(x_test, y_test))
# Out:
# ['pointer' 'left_click' 'hold_drag' 'pointer' 'hold_drag' 'hold_drag'
#  'hold_drag' 'hold_drag' 'pointer' 'hold_drag' 'pointer' 'hold_drag'
#  'left_click' 'right_click' 'right_click' 'pointer' 'left_click' 'pointer'
#  'left_click' 'left_click' 'hold_drag' 'pointer' 'pointer' 'pointer'
#  'hold_drag' 'hold_drag' 'pointer' 'pointer' 'hold_drag' 'hold_drag'
#  'pointer' 'left_click' 'hold_drag' 'pointer' 'pointer' 'hold_drag'
#  'left_click' 'pointer' 'right_click' 'pointer' 'hold_drag' 'left_click'
#  'pointer' 'hold_drag' 'left_click' 'hold_drag' 'hold_drag' 'hold_drag'
#  'pointer' 'pointer' 'pointer' 'pointer' 'right_click' 'left_click'
#  'pointer' 'hold_drag' 'left_click' 'hold_drag' 'hold_drag' 'left_click'
#  'left_click' 'left_click' 'left_click' 'left_click' 'pointer' 'pointer'
#  'left_click' 'pointer' 'left_click' 'hold_drag' 'left_click' 'left_click'
#  'pointer' 'pointer' 'pointer' 'hold_drag' 'right_click' 'pointer'
#  'hold_drag' 'pointer' 'left_click' 'pointer' 'left_click' 'left_click'
#  'left_click' 'left_click' 'pointer' 'pointer' 'hold_drag' 'pointer'
#  'pointer' 'hold_drag' 'left_click' 'hold_drag' 'left_click' 'left_click'
#  'hold_drag' 'hold_drag' 'hold_drag' 'pointer' 'left_click' 'pointer'
#  'right_click' 'left_click' 'pointer' 'pointer' 'left_click' 'pointer'
#  'left_click' 'left_click' 'left_click' 'pointer' 'hold_drag' 'pointer'
#  'pointer' 'left_click' 'right_click' 'left_click' 'hold_drag' 'hold_drag'
#  'hold_drag' 'hold_drag' 'hold_drag' 'left_click' 'hold_drag'
#  'right_click' 'pointer' 'pointer' 'hold_drag' 'pointer' 'left_click'
#  'left_click' 'hold_drag' 'left_click' 'hold_drag' 'pointer' 'hold_drag'
#  'left_click' 'right_click' 'pointer' 'pointer' 'pointer' 'pointer'
#  'hold_drag' 'hold_drag' 'right_click' 'hold_drag' 'hold_drag'
#  'left_click' 'pointer' 'right_click' 'hold_drag' 'hold_drag' 'left_click'
#  'pointer' 'hold_drag' 'pointer' 'pointer' 'left_click' 'right_click'
#  'pointer' 'pointer' 'left_click' 'hold_drag' 'hold_drag' 'left_click'
#  'left_click' 'pointer' 'pointer' 'left_click' 'hold_drag' 'left_click'
#  'pointer' 'left_click' 'hold_drag' 'right_click' 'left_click' 'hold_drag'
#  'pointer' 'pointer' 'hold_drag' 'hold_drag' 'left_click' 'pointer'
#  'hold_drag' 'pointer' 'pointer' 'hold_drag' 'left_click' 'pointer'
#  'left_click' 'hold_drag' 'left_click' 'pointer' 'left_click'
#  'right_click' 'hold_drag' 'left_click' 'pointer' 'hold_drag' 'pointer'
#  'left_click' 'hold_drag' 'hold_drag' 'pointer' 'hold_drag' 'hold_drag'
#  'right_click' 'pointer' 'left_click' 'hold_drag' 'left_click' 'pointer'
#  'pointer' 'left_click' 'right_click' 'pointer' 'hold_drag' 'pointer'
#  'hold_drag' 'left_click' 'left_click' 'pointer' 'hold_drag' 'pointer'
#  'hold_drag' 'pointer' 'pointer']
# training 0.9977973568281938
# validation 0.6754385964912281

# %% [markdown]
# K-Means

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=
#        3, 1, 2, 3, 2, 0, 0, 1, 0, 1, 1, 0, 2, 1, 1, 0, 3, 2, 1, 1, 2, 2,
#        3, 2, 3, 3, 2, 2, 1, 2, 2, 0, 1, 3, 2, 1, 0, 2, 0, 0, 0, 0, 2, 1,
#        2, 3, 2, 2, 2, 3, 3, 1, 3, 0, 2, 1, 1, 1, 2, 3, 3, 3, 1, 0, 2, 2,
#        0, 2, 2, 1, 1, 2, 2, 1, 1, 3, 2, 2, 3, 2, 1, 0, 0, 2, 1, 1, 1, 2,
#        3, 0, 2, 1, 3, 0, 0, 2, 0, 0, 2, 2, 3, 0, 2, 3, 2, 1, 1, 1, 0, 1,
#        1, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 0, 1, 2, 3, 1, 1, 2, 1, 1, 1, 0,
#        3, 1, 1, 3, 0, 0, 1, 2, 0, 2, 3, 0, 3, 1, 1, 0, 0, 2, 1, 2, 3, 1,
#        1, 0, 3, 2, 0, 2, 1, 1, 1, 2, 2, 2, 1, 2, 3, 1, 1, 3, 2, 0, 3, 0,
#        0, 1, 0, 1, 1, 1, 0, 3, 1, 2, 2, 3, 0, 0, 1, 0, 1, 1, 0, 3, 1, 0,
#        2, 1, 0, 1, 1, 2, 0, 2, 0, 3, 1, 3, 0, 2, 2, 2, 3, 0, 3, 3, 1, 0,
#        2, 3, 3, 2, 3, 1, 2, 1, 3, 0, 2, 3, 2, 0, 2, 2, 2, 2, 1, 2, 2, 3,
#        2, 1, 2, 0, 0, 0, 1, 2, 3, 1, 2, 0, 0, 3, 1, 0, 1, 2, 1, 0, 0, 0,
#        0, 2, 3, 3, 3, 1, 2, 2, 2, 0, 0, 3, 1, 1, 2, 2, 3, 0, 0, 0, 0, 2,
#        2, 3, 2, 2, 3, 2, 2, 0, 0, 2, 1, 0, 2, 3, 1, 0, 0, 2, 2, 2, 3, 0,
#        3, 2, 0, 3, 1, 0, 2, 2, 3, 1, 0, 0, 0, 2, 0, 2, 2, 1, 0, 3, 2, 3,
#        2, 2, 2, 0, 3, 0, 0, 2, 1, 0, 2, 1, 2, 1, 3, 1, 0, 0, 2, 1, 2, 1,
#        1, 1, 2, 2, 0, 3, 1, 0, 0, 2, 1, 1, 0, 1, 0, 0, 2, 1, 2, 0, 0, 2,
#        0, 1, 2, 0, 2, 1, 3, 1, 2, 0, 0, 2, 3, 0, 2, 3, 3, 1, 0, 1, 3, 2,
#        1, 1, 3, 3, 2, 0, 3, 1, 2, 1, 1, 2, 2, 3, 3, 2, 3, 3, 3, 3, 3, 3,
#        2, 0, 1, 3, 1, 1], dtype=int32)

# %%
y_train
# Out:
# 599         left_click
# 764     left_dbl_click
# 543         left_click
# 423         left_click
# 1120           pointer
#              ...
# 1130           pointer
# 1294       right_click
# 860            pointer
# 1459          scrollup
# 1126           pointer
# Name: class_type, Length: 1208, dtype: object

# %%
classes = {"pointer":0,"left_click":1,"right_click":2,"hold_drag":3,"left_dbl_click":4,"scrolldown":5,"scrollup":6,"right_arrow":7,"left_arrow":8}
one_hot_y_train = []
for label in y_train:
  row = np.zeros(9)
  row[classes[label]] = 1
  one_hot_y_train.append(row)

one_hot_y_test = []
for label in y_test:
  row = np.zeros(9)
  row[classes[label]] = 1
  one_hot_y_test.append(row)

# %%
one_hot_y_train = np.array(one_hot_y_train)
one_hot_y_test = np.array(one_hot_y_test)

# %% [markdown]
# DL Model

# %%
from keras.models import Sequential 
from keras.layers import Dense, Dropout
from keras.layers import Convolution2D, MaxPool2D
from tensorflow.keras.optimizers import Adam
import tensorflow as tf

# %%
model = Sequential()

model.add(Dense(63, input_shape = (63,),activation = 'relu'))
model.add(Dropout(0.1))

model.add(Dense(128,activation = 'relu'))
model.add(Dropout(0.25))

model.add(Dense(128,activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(9, activation= 'softmax'))

model.compile(loss= 'categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
history = model.fit(x_train,one_hot_y_train, batch_size = 16 , epochs = 100, validation_data=(x_test,one_hot_y_test))
# Out:
# Epoch 1/100
# 76/76 [==============================] - 4s 11ms/step - loss: 2.0245 - accuracy: 0.2219 - val_loss: 1.9054 - val_accuracy: 0.3333
# Epoch 2/100
# 76/76 [==============================] - 0s 6ms/step - loss: 1.8993 - accuracy: 0.2483 - val_loss: 1.7700 - val_accuracy: 0.3366
# Epoch 3/100
# 76/76 [==============================] - 0s 6ms/step - loss: 1.7547 - accuracy: 0.2930 - val_loss: 1.5798 - val_accuracy: 0.4257
# Epoch 4/100
# 76/76 [==============================] - 0s 5ms/step - loss: 1.5180 - accuracy: 0.4296 - val_loss: 1.3048 - val_accuracy: 0.5941
# Epoch 5/100
# 76/76 [==============================] - 0s 6ms/step - loss: 1.2988 - accuracy: 0.5041 - val_loss: 1.1935 - val_accuracy: 0.5314
# Epoch 6/100
# 76/76 [==============================] - 1s 9ms/step - loss: 1.1388 - accuracy: 0.5555 - val_loss: 0.9690 - val_accuracy: 0.5842
# Epoch 7/100
# 76/76 [==============================] - 1s 11ms/step - loss: 1.0395 - accuracy: 0.5811 - val_loss: 0.8851 - val_accuracy: 0.6601
# Epoch 8/100
# 76/76 [==============================] - 1s 10ms/step - loss: 0.9174 - accuracy: 0.6374 - val_loss: 0.8571 - val_accuracy: 0.6436
# Epoch 9/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.8423 - accuracy: 0.6714 - val_loss: 0.8049 - val_accuracy: 0.6766
# Epoch 10/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.7589 - accuracy: 0.7020 - val_loss: 0.7632 - val_accuracy: 0.7063
# Epoch 11/100
# 76/76 [==============================] - 1s 12ms/step - loss: 0.7581 - accuracy: 0.6887 - val_loss: 0.8160 - val_accuracy: 0.6799
# Epoch 12/100
# 76/76 [==============================] - 1s 10ms/step - loss: 0.6792 - accuracy: 0.7310 - val_loss: 0.6985 - val_accuracy: 0.6898
# Epoch 13/100
# 76/76 [==============================] - 1s 10ms/step - loss: 0.6910 - accuracy: 0
100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2806 - accuracy: 0.8957 - val_loss: 0.4511 - val_accuracy: 0.8383
# Epoch 75/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.3054 - accuracy: 0.8899 - val_loss: 0.3503 - val_accuracy: 0.8911
# Epoch 76/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2868 - accuracy: 0.9031 - val_loss: 0.3760 - val_accuracy: 0.8845
# Epoch 77/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.3020 - accuracy: 0.8916 - val_loss: 0.4198 - val_accuracy: 0.8449
# Epoch 78/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2744 - accuracy: 0.9098 - val_loss: 0.3957 - val_accuracy: 0.8779
# Epoch 79/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2562 - accuracy: 0.9073 - val_loss: 0.3850 - val_accuracy: 0.8779
# Epoch 80/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2517 - accuracy: 0.9106 - val_loss: 0.5408 - val_accuracy: 0.8383
# Epoch 81/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.3274 - accuracy: 0.8924 - val_loss: 0.4936 - val_accuracy: 0.8482
# Epoch 82/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.3249 - accuracy: 0.8899 - val_loss: 0.3535 - val_accuracy: 0.8944
# Epoch 83/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.2475 - accuracy: 0.9073 - val_loss: 0.4218 - val_accuracy: 0.8779
# Epoch 84/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2531 - accuracy: 0.8990 - val_loss: 0.3830 - val_accuracy: 0.8779
# Epoch 85/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2563 - accuracy: 0.9147 - val_loss: 0.4657 - val_accuracy: 0.8251
# Epoch 86/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2660 - accuracy: 0.9048 - val_loss: 0.3403 - val_accuracy: 0.8845
# Epoch 87/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2413 - accuracy: 0.9139 - val_loss: 0.3231 - val_accuracy: 0.9076
# Epoch 88/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2469 - accuracy: 0.9205 - val_loss: 0.3180 - val_accuracy: 0.9076
# Epoch 89/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2534 - accuracy: 0.9123 - val_loss: 0.4104 - val_accuracy: 0.8713
# Epoch 90/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.2416 - accuracy: 0.9147 - val_loss: 0.3528 - val_accuracy: 0.9010
# Epoch 91/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.2407 - accuracy: 0.9180 - val_loss: 0.3727 - val_accuracy: 0.8878
# Epoch 92/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.2813 - accuracy: 0.9031 - val_loss: 0.4231 - val_accuracy: 0.8812
# Epoch 93/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2613 - accuracy: 0.9040 - val_loss: 0.3352 - val_accuracy: 0.9043
# Epoch 94/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2301 - accuracy: 0.9247 - val_loss: 0.3818 - val_accuracy: 0.8680
# Epoch 95/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.2269 - accuracy: 0.9205 - val_loss: 0.6395 - val_accuracy: 0.8383
# Epoch 96/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2575 - accuracy: 0.9114 - val_loss: 0.3517 - val_accuracy: 0.9109
# Epoch 97/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.2778 - accuracy: 0.9031 - val_loss: 0.3976 - val_accuracy: 0.8779
# Epoch 98/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2239 - accuracy: 0.9247 - val_loss: 0.3641 - val_accuracy: 0.8878
# Epoch 99/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.2075 - accuracy: 0.9371 - val_loss: 0.3390 - val_accuracy: 0.9109
# Epoch 100/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.2065 - accuracy: 0.9305 - val_loss: 0.3415 - val_accuracy: 0.9142

# %%
filename = 'DL_model_3.sav'
pickle.dump(model, open(filename, 'wb'))
# Out:
# INFO:tensorflow:Assets written to: ram://e16a05f2-c760-46c4-b520-bcd0c3728da1/assets

# %%
model.save('DL_model_3.h5')
